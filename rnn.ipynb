# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline  
from sklearn import preprocessing 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from __future__ import division
from sklearn.decomposition import TruncatedSVD
from sklearn.utils import shuffle
from tensorflow.contrib import rnn

# %%
train = pd.read_table("data_content", header=None, skip_blank_lines=False)
label = pd.read_table("label", header=None, dtype='category', skip_blank_lines=False)

# %%
train.columns = ['question']
label.columns = ['group']

# %%
print train.shape
print label.shape
# Out:
# (67213, 1)
# (67213, 1)

# %%
ratio = 0.2
# Separate each muscle group data
chest = train[label['group']=='Chest']
chest_label = label[label['group']=='Chest']
chest_len = int(chest.shape[0]*ratio)

shoulder = train[label['group']=='Shoulders']
shoulder_len = int(shoulder.shape[0]*ratio)
shoulder_label = label[label['group']=='Shoulders']

back = train[label['group']=='Back']
back_label = label[label['group']=='Back']
back_len = int(back.shape[0]*ratio)

leg = train[label['group']=='Leg']
leg_label = label[label['group']=='Leg']
leg_len = int(leg.shape[0]*ratio)

tricep = train[label['group']=='Triceps']
tricep_label = label[label['group']=='Triceps']
tricep_len = int(tricep.shape[0]*ratio)

bicep = train[label['group']=='Biceps']
bicep_label = label[label['group']=='Biceps']
bicep_len = int(bicep.shape[0]*ratio)

ab = train[label['group']=='Abs']
ab_label = label[label['group']=='Abs']
ab_len = int(ab.shape[0]*ratio)

glute = train[label['group']=='Glutes']
glute_label = label[label['group']=='Glutes']
glute_len = int(glute.shape[0]*ratio)

# %%
# Take only the top ratio% of each group of data
train_data = pd.concat([chest[0:chest_len], shoulder[0:shoulder_len], back[0:back_len], 
                        leg[0:leg_len], tricep[0:tricep_len], bicep[0:bicep_len], ab[0:ab_len], glute[0: glute_len]])
print train_data.shape
train_label = pd.concat([chest_label[0:chest_len], shoulder_label[0:shoulder_len], back_label[0:back_len], 
                   leg_label[0:leg_len], tricep_label[0:tricep_len], bicep_label[0:bicep_len], ab_label[0:ab_len],
                         glute_label[0: glute_len]])
print train_label.shape
# Out:
# (13440, 1)
# (13440, 1)

# %%
y_label = pd.Series(train_label['group'],dtype='category')
y_label.cat.categories 
y_label.cat.categories = [0,1,2,3,4,5,6,7]

# %%
#label binizer
lb = preprocessing.LabelBinarizer()
lb.fit([0,1,2,3,4,5,6,7])
label = lb.transform(y_label)

# %%
#initialize TFIDF vectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2),stop_words="english")
data = vectorizer.fit_transform(train_data['question'])

# %%
# reduce features using SVD
SVD = TruncatedSVD(n_components=100, n_iter=5, random_state=0)
train = SVD.fit_transform(data)

# %%
# shuffle data
train, label = shuffle(train, label, random_state=0)

# %%
# train test split
train_data, testX, train_label, testY = train_test_split(train, label, test_size=0.2, random_state=0)
print train_data.shape
print train_label.shape
# Out:
# (10752, 100)
# (10752, 8)

# %%
# tensorflow setup

# Parameters
learning_rate = 0.001
training_iters = 10000
batch_size = 128
display_step = 10

# Network Parameters
n_input = train_data.shape[1]
n_hidden = 128 # hidden layer num of features
n_steps = 1
n_classes = 8

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}


def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, n_steps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

pred = RNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
train_data = train_data.reshape(10752,1,100)

# %%
# tensorflow session
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)


cost_a = 0
diff = 1
epoch_values=[]
accuracy_values=[]
cost_values=[]

# Training epochs
for i in range(training_iters):
    if i > 1 and diff < .0001:
        print("change in cost %g; convergence."%diff)
        break
    else:
        # Run training step
        step = sess.run(optimizer, feed_dict={x: train_data, y: train_label})
        # Report occasional stats
        if i % 10 == 0:
            # Add epoch to epoch_values
            epoch_values.append(i)
            # Generate accuracy stats on test data
            train_accuracy, newCost = sess.run(
                [accuracy, cost], 
                feed_dict={x: train_data, y: train_label}
            )
            # Add accuracy to live graphing variable
            accuracy_values.append(train_accuracy)
            # Add cost to live graphing variable
            cost_values.append(newCost)
            
            # Re-assign values for variables
            diff = abs(newCost - cost_a)
            cost_a = newCost

            #generate print statements
            print("step %d, training accuracy %g"%(i, train_accuracy))
            print("step %d, cost %g"%(i, newCost))
            print("step %d, change in cost %g"%(i, diff))

            

# How well do we perform on held-out test data?
print("final accuracy on test set: %s" %str(sess.run(accuracy, 
                                                     feed_dict={x: testX, 
                                                                y: testY})))
# Out:
# step 0, training accuracy 0.0912388
# step 0, cost 2.83752
# step 0, change in cost 2.83752
# step 10, training accuracy 0.0916109
# step 10, cost 2.6932
# step 10, change in cost 0.144315
# step 20, training accuracy 0.0917969
# step 20, cost 2.55473
# step 20, change in cost 0.138469
# step 30, training accuracy 0.0963542
# step 30, cost 2.42269
# step 30, change in cost 0.132039
# step 40, training accuracy 0.118676
# step 40, cost 2.30279
# step 40, change in cost 0.119906
# step 50, training accuracy 0.19708
# step 50, cost 2.20185
# step 50, change in cost 0.100939
# step 60, training accuracy 0.249349
# step 60, cost 2.12315
# step 60, change in cost 0.078701
# step 70, training accuracy 0.257161
# step 70, cost 2.06384
# step 70, change in cost 0.0593033
# step 80, training accuracy 0.257812
# step 80, cost 2.01801
# step 80, change in cost 0.0458345
# step 90, training accuracy 0.257626
# step 90, cost 1.9817
# step 90, change in cost 0.0363147
# step 100, training accuracy 0.25865
# step 100, cost 1.95374
# step 100, change in cost 0.0279514
# step 110, training accuracy 0.259766
# step 110, cost 1.93384
# step 110, change in cost 0.0199072
# step 120, training accuracy 0.260603
# step 120, cost 1.92117
# step 120, change in cost 0.0126619
# step 130, training accuracy 0.261068
# step 130, cost 1.91404
# step 130, change in cost 0.00713325
# step 140, training accuracy 0.261068
# step 140, cost 1.91018
# step 140, change in cost 0.00386107
# step 150, training accuracy 0.261161
# step 150, cost 1.90778
# step 150, change in cost 0.00239813
# step 160, training accuracy 0.261626
# step 160, cost 1.90598
# step 160, change in cost 0.00180638
# step 170, training accuracy 0.26144
# step 170, cost 1.90448
# step 170, change in cost 0.00150049
# step 180, training accuracy 0.261347
# step 180, cost 1.90318
# step 180, change in cost 0.0012908
# step 190, training accuracy 0.261533
# step 190, cost 1.90204
# step 190, change in cost 0.00114262
# step 200, training accuracy 0.261626
# step 200, cost 1.901
# step 200, change in cost 0.00104082
# step 210, training accuracy 0.261998
# step 210, cost 1.90003
# step 210, change in cost 0.00096643
# step 220, training accuracy 0.262463
# step 220, cost 1.89913
# step 220, change in cost 0.000908256
# step 230, training accuracy 0.262835
# step 230, cost 1.89826
# step 230, change in cost 0.000869393
# step 240, training accuracy 0.263207
# step 240, cost 1.89742
# step 240, change in cost 0.000833035
# step 250, training accuracy 0.263579
# step 250, cost 1.89661
# step 250, change in cost 0.00080955
# step 260, training accuracy 0.263765
# step 260, cost 1.89582
# step 260, change in cost 0.000793695
# step 270, training accuracy 0.263486
# step 270, cost 1.89504
# step 270, change in cost 0.000779629
# step 280, training accuracy 0.263207
# step 280, cost 1.89427
# step 280, change in cost 0.000775456
# step 290, training accuracy 0.263207
# step 290, cost 1.89349
# step 290, change in cost 0.000772476
# step 300, training accuracy 0.263114
# step 300, cost 1.89272
# step 300, change in cost 0.000773907
# step 310, training accuracy 0.2633
# step 310, cost 1.89194
# step 310, change in cost 0.000777841
# step 320, training accuracy 0.2633
# step 320, cost 1.89116
# step 320, change in cost 0.000786424
# step 330, training accuracy 0.263486
# step 330, cost 1.89036
# step 330, change in cost 0.000795245
# step 340, training accuracy 0.263672
# step 340, cost 1.88955
# step 340, change in cost 0.000810981
# step 350, training accuracy 0.263672
# step 350, cost 1.88873
# step 350, change in cost 0.000823021
# step 360, training accuracy 0.264044
# step 360, cost 1.88789
# step 360, change in cost 0.000838637
# step 370, training accuracy 0.26423
# step 370, cost 1.88703
# step 370, change in cost 0.00085938
# step 380, training accuracy 0.26423
# step 380, cost 1.88615
# step 380, change in cost 0.000877857
# step 390, training accuracy 0.264137
# step 390, cost 1.88525
# step 390, change in cost 0.000897288
# step 400, training accuracy 0.264323
# step 400, cost 1.88433
# step 400, change in cost 0.000921369
# step 410, training accuracy 0.264509
# step 410, cost 1.88339
# step 410, change in cost 0.00094223
# step 420, training accuracy 0.264323
# step 420, cost 1.88242
# step 420, change in cost 0.000966549
# step 430, training accuracy 0.264509
# step 430, cost 1.88143
# step 430, change in cost 0.000988722
# step 440, training accuracy 0.264695
# step 440, cost 1.88042
# step 440, change in cost 0.00101459
# step 450, training accuracy 0.264974
# step 450, cost 1.87938
# step 450, change in cost 0.00103664
# step 460, training accuracy 0.264974
# step 460, cost 1.87832
# step 460, change in cost 0.00106144
# step 470, training accuracy 0.265439
# step 470, cost 1.87724
# step 470, change in cost 0.00108302
# step 480, training accuracy 0.265346
# step 480, cost 1.87613
# step 480, change in cost 0.00110853
# step 490, training accuracy 0.265253
# step 490, cost 1.875
# step 490, change in cost 0.00113082
# step 500, training accuracy 0.265439
# step 500, cost 1.87385
# step 500, change in cost 0.00115275
# step 510, training accuracy 0.265532
# step 510, cost 1.87267
# step 510, change in cost 0.00117445
# step 520, training accuracy 0.265718
# step 520, cost 1.87148
# step 520, change in cost 0.00119591
# step 530, training accuracy 0.265718
# step 530, cost 1.87026
# step 530, change in cost 0.00121641
# step 540, training accuracy 0.265625
# step 540, cost 1.86902
# step 540, change in cost 0.00123465
# step 550, training accuracy 0.265811
# step 550, cost 1.86777
# step 550, change in cost 0.00125337
# step 560, training accuracy 0.266555
# step 560, cost 1.8665
# step 560, change in cost 0.00127149
# step 570, training accuracy 0.266927
# step 570, cost 1.86521
# step 570, change in cost 0.0012902
# step 580, training accuracy 0.267392
# step 580, cost 1.86391
# step 580, change in cost 0.00130427
# step 590, training accuracy 0.268043
# step 590, cost 1.86258
# step 590, change in cost 0.00132191
# step 600, training accuracy 0.268322
# step 600, cost 1.86125
# step 600, change in cost 0.00133348
# step 610, training accuracy 0.268229
# step 610, cost 1.8599
# step 610, change in cost 0.00134897
# step 620, training accuracy 0.268601
# step 620, cost 1.85854
# step 620, change in cost 0.0013622
# step 630, training accuracy 0.268973
# step 630, cost 1.85716
# step 630, change in cost 0.00137401
# step 640, training accuracy 0.269066
# step 640, cost 1.85578
# step 640, change in cost 0.00138652
# step 650, training accuracy 0.269531
# step 650, cost 1.85438
# step 650, change in cost 0.00139856
# step 660, training accuracy 0.269624
# step 660, cost 1.85297
# step 660, change in cost 0.00140834
# step 670, training accuracy 0.269996
# step 670, cost 1.85155
# step 670, change in cost 0.00141764
# step 680, training accuracy 0.270461
# step 680, cost 1.85012
# step 680, change in cost 0.00143051
# step 690, training accuracy 0.270554
# step 690, cost 1.84869
# step 690, change in cost 0.00143802
# step 700, training accuracy 0.270647
# step 700, cost 1.84724
# step 700, change in cost 0.00144768
# step 710, training accuracy 0.271391
# step 710, cost 1.84578
# step 710, change in cost 0.00145638
# step 720, training accuracy 0.271577
# step 720, cost 1.84431
# step 720, change in cost 0.00146699
# step 730, training accuracy 0.271856
# step 730, cost 1.84284
# step 730, change in cost 0.0014739
# step 740, training accuracy 0.272228
# step 740, cost 1.84136
# step 740, change in cost 0.00148344
# step 750, training accuracy 0.272693
# step 750, cost 1.83986
# step 750, change in cost 0.00149238
# step 760, training accuracy 0.272972
# step 760, cost 1.83836
# step 760, change in cost 0.00150013
# step 770, training accuracy 0.273624
# step 770, cost 1.83686
# step 770, change in cost 0.00150776
# step 780, training accuracy 0.274182
# step 780, cost 1.83534
# step 780, change in cost 0.00151706
# step 790, training accuracy 0.274275
# step 790, cost 1.83381
# step 790, change in cost 0.0015254
# step 800, training accuracy 0.274461
# step 800, cost 1.83228
# step 800, change in cost 0.00153255
# step 810, training accuracy 0.27474
# step 810, cost 1.83074
# step 810, change in cost 0.00154185
# step 820, training accuracy 0.275205
# step 820, cost 1.82919
# step 820, change in cost 0.00155008
# step 830, training accuracy 0.27567
# step 830, cost 1.82763
# step 830, change in cost 0.00155842
# step 840, training accuracy 0.275763
# step 840, cost 1.82607
# step 840, change in cost 0.00156546
# step 850, training accuracy 0.276228
# step 850, cost 1.82449
# step 850, change in cost 0.00157309
# step 860, training accuracy 0.276228
# step 860, cost 1.82291
# step 860, change in cost 0.00158262
# step 870, training accuracy 0.277251
# step 870, cost 1.82132
# step 870, change in cost 0.00159049
# step 880, training accuracy 0.277995
# step 880, cost 1.81972
# step 880, change in cost 0.00159669
# step 890, training accuracy 0.278367
# step 890, cost 1.81811
# step 890, change in cost 0.00160801
# step 900, training accuracy 0.278925
# step 900, cost 1.8165
# step 900, change in cost 0.00161386
# step 910, training accuracy 0.279204
# step 910, cost 1.81488
# step 910, change in cost 0.00162125
# step 920, training accuracy 0.279762
# step 920, cost 1.81325
# step 920, change in cost 0.00162995
# step 930, training accuracy 0.280227
# step 930, cost 1.81161
# step 930, change in cost 0.00163627
# step 940, training accuracy 0.280878
# step 940, cost 1.80997
# step 940, change in cost 0.00164652
# step 950, training accuracy 0.281157
# step 950, cost 1.80832
# step 950, change in cost 0.00165045
# step 960, training accuracy 0.281529
# step 960, cost 1.80666
# step 960, change in cost 0.0016613
# step 970, training accuracy 0.281715
# step 970, cost 1.80499
# step 970, change in cost 0.00166667
# step 980, training accuracy 0.281901
# step 980, cost 1.80332
# step 980, change in cost 0.0016731
# step 990, training accuracy 0.28218
# step 990, cost 1.80163
# step 990, change in cost 0.00168228
# step 1000, training accuracy 0.282552
# step 1000, cost 1.79995
# step 1000, change in cost 0.00168645
# step 1010, training accuracy 0.282924
# step 1010, cost 1.79825
# step 1010, change in cost 0.00169492
# step 1020, training accuracy 0.283575
# step 1020, cost 1.79655
# step 1020, change in cost 0.00170052
# step 1030, training accuracy 0.283947
# step 1030, cost 1.79484
# step 1030, change in cost 0.00170755
# step 1040, training accuracy 0.28404
# step 1040, cost 1.79313
# step 1040, change in cost 0.00171423
# step 1050, training accuracy 0.284505
# step 1050, cost 1.79141
# step 1050, change in cost 0.00171721
# step 1060, training accuracy 0.285063
# step 1060, cost 1.78969
# step 1060, change in cost 0.00172555
# step 1070, training accuracy 0.285528
# step 1070, cost 1.78796
# step 1070, change in cost 0.00173128
# step 1080, training accuracy 0.286086
# step 1080, cost 1.78622
# step 1080, change in cost 0.00173569
# step 1090, training accuracy 0.286458
# step 1090, cost 1.78448
# step 1090, change in cost 0.00174475
# step 1100, training accuracy 0.286923
# step 1100, cost 1.78273
# step 1100, change in cost 0.00174558
# step 1110, training accuracy 0.287481
# step 1110, cost 1.78098
# step 1110, change in cost 0.00175142
# step 1120, training accuracy 0.287946
# step 1120, cost 1.77922
# step 1120, change in cost 0.00175893
# step 1130, training accuracy 0.288132
# step 1130, cost 1.77746
# step 1130, change in cost 0.00176382
# step 1140, training accuracy 0.288969
# step 1140, cost 1.77569
# step 1140, change in cost 0.00176847
# step 1150, training accuracy 0.289249
# step 1150, cost 1.77391
# step 1150, change in cost 0.00177193
# step 1160, training accuracy 0.289156
# step 1160, cost 1.77214
# step 1160, change in cost 0.00177801
# step 1170, training accuracy 0.289714
# step 1170, cost 1.77035
# step 1170, change in cost 0.00178349
# step 1180, training accuracy 0.290458
# step 1180, cost 1.76857
# step 1180, change in cost 0.00178659
# step 1190, training accuracy 0.291016
# step 1190, cost 1.76677
# step 1190, change in cost 0.00179255
# step 1200, training accuracy 0.291109
# step 1200, cost 1.76498
# step 1200, change in cost 0.00179613
# step 1210, training accuracy 0.291388
# step 1210, cost 1.76318
# step 1210, change in cost 0.00180125
# step 1220, training accuracy 0.291853
# step 1220, cost 1.76137
# step 1220, change in cost 0.00180554
# step 1230, training accuracy 0.292225
# step 1230, cost 1.75956
# step 1230, change in cost 0.00180864
# step 1240, training accuracy 0.292597
# step 1240, cost 1.75775
# step 1240, change in cost 0.00181377
# step 1250, training accuracy 0.293155
# step 1250, cost 1.75593
# step 1250, change in cost 0.00181842
# step 1260, training accuracy 0.293992
# step 1260, cost 1.75411
# step 1260, change in cost 0.00182152
# step 1270, training accuracy 0.294178
# step 1270, cost 1.75228
# step 1270, change in cost 0.00182819
# step 1280, training accuracy 0.294643
# step 1280, cost 1.75045
# step 1280, change in cost 0.00182819
# step 1290, training accuracy 0.295201
# step 1290, cost 1.74862
# step 1290, change in cost 0.0018357
# step 1300, training accuracy 0.295573
# step 1300, cost 1.74678
# step 1300, change in cost 0.00184
# step 1310, training accuracy 0.295945
# step 1310, cost 1.74493
# step 1310, change in cost 0.00184286
# step 1320, training accuracy 0.296689
# step 1320, cost 1.74309
# step 1320, change in cost 0.00184774
# step 1330, training accuracy 0.296968
# step 1330, cost 1.74123
# step 1330, change in cost 0.00185215
# step 1340, training accuracy 0.297154
# step 1340, cost 1.73938
# step 1340, change in cost 0.00185633
# step 1350, training accuracy 0.297805
# step 1350, cost 1.73752
# step 1350, change in cost 0.00186062
# step 1360, training accuracy 0.298735
# step 1360, cost 1.73565
# step 1360, change in cost 0.00186288
# step 1370, training accuracy 0.299107
# step 1370, cost 1.73379
# step 1370, change in cost 0.0018692
# step 1380, training accuracy 0.298828
# step 1380, cost 1.73191
# step 1380, change in cost 0.00187159
# step 1390, training accuracy 0.299293
# step 1390, cost 1.73004
# step 1390, change in cost 0.00187719
# step 1400, training accuracy 0.300037
# step 1400, cost 1.72815
# step 1400, change in cost 0.00188291
# step 1410, training accuracy 0.300595
# step 1410, cost 1.72627
# step 1410, change in cost 0.0018847
# step 1420, training accuracy 0.30106
# step 1420, cost 1.72438
# step 1420, change in cost 0.00189066
# step 1430, training accuracy 0.301804
# step 1430, cost 1.72249
# step 1430, change in cost 0.00189257
# step 1440, training accuracy 0.302269
# step 1440, cost 1.72059
# step 1440, change in cost 0.00190008
# step 1450, training accuracy 0.30292
# step 1450, cost 1.71868
# step 1450, change in cost 0.00190282
# step 1460, training accuracy 0.303106
# step 1460, cost 1.71677
# step 1460, change in cost 0.0019089
# step 1470, training accuracy 0.303478
# step 1470, cost 1.71486
# step 1470, change in cost 0.001912
# step 1480, training accuracy 0.304408
# step 1480, cost 1.71295
# step 1480, change in cost 0.00191498
# step 1490, training accuracy 0.304036
# step 1490, cost 1.71103
# step 1490, change in cost 0.0019213
# step 1500, training accuracy 0.304408
# step 1500, cost 1.7091
# step 1500, change in cost 0.00192595
# step 1510, training accuracy 0.304781
# step 1510, cost 1.70717
# step 1510, change in cost 0.00193095
# step 1520, training accuracy 0.305153
# step 1520, cost 1.70524
# step 1520, change in cost 0.00193191
# step 1530, training accuracy 0.305897
# step 1530, cost 1.7033
# step 1530, change in cost 0.00194025
# step 1540, training accuracy 0.306083
# step 1540, cost 1.70135
# step 1540, change in cost 0.00194395
# step 1550, training accuracy 0.306455
# step 1550, cost 1.69941
# step 1550, change in cost 0.00194657
# step 1560, training accuracy 0.307385
# step 1560, cost 1.69745
# step 1560, change in cost 0.00195336
# step 1570, training accuracy 0.307664
# step 1570, cost 1.69549
# step 1570, change in cost 0.00195873
# step 1580, training accuracy 0.308594
# step 1580, cost 1.69353
# step 1580, change in cost 0.00196183
# step 1590, training accuracy 0.309338
# step 1590, cost 1.69157
# step 1590, change in cost 0.00196588
# step 1600, training accuracy 0.310082
# step 1600, cost 1.6896
# step 1600, change in cost 0.00197053
# step 1610, training accuracy 0.310454
# step 1610, cost 1.68762
# step 1610, change in cost 0.0019753
# step 1620, training accuracy 0.310826
# step 1620, cost 1.68564
# step 1620, change in cost 0.00198042
# step 1630, training accuracy 0.311291
# step 1630, cost 1.68366
# step 1630, change in cost 0.00198436
# step 1640, training accuracy 0.31157
# step 1640, cost 1.68167
# step 1640, change in cost 0.00198877
# step 1650, training accuracy 0.311756
# step 1650, cost 1.67967
# step 1650, change in cost 0.00199342
# step 1660, training accuracy 0.312221
# step 1660, cost 1.67768
# step 1660, change in cost 0.00199676
# step 1670, training accuracy 0.312407
# step 1670, cost 1.67567
# step 1670, change in cost 0.00200284
# step 1680, training accuracy 0.313058
# step 1680, cost 1.67367
# step 1680, change in cost 0.00200486
# step 1690, training accuracy 0.313058
# step 1690, cost 1.67166
# step 1690, change in cost 0.00201094
# step 1700, training accuracy 0.313616
# step 1700, cost 1.66964
# step 1700, change in cost 0.0020138
# step 1710, training accuracy 0.314174
# step 1710, cost 1.66762
# step 1710, change in cost 0.00201976
# step 1720, training accuracy 0.314639
# step 1720, cost 1.6656
# step 1720, change in cost 0.00202358
# step 1730, training accuracy 0.314825
# step 1730, cost 1.66357
# step 1730, change in cost 0.00202584
# step 1740, training accuracy 0.31529
# step 1740, cost 1.66154
# step 1740, change in cost 0.00203192
# step 1750, training accuracy 0.316034
# step 1750, cost 1.65951
# step 1750, change in cost 0.00203383
# step 1760, training accuracy 0.316034
# step 1760, cost 1.65747
# step 1760, change in cost 0.00203955
# step 1770, training accuracy 0.316313
# step 1770, cost 1.65543
# step 1770, change in cost 0.00204456
# step 1780, training accuracy 0.316499
# step 1780, cost 1.65338
# step 1780, change in cost 0.00204444
# step 1790, training accuracy 0.316871
# step 1790, cost 1.65133
# step 1790, change in cost 0.00205052
# step 1800, training accuracy 0.317615
# step 1800, cost 1.64928
# step 1800, change in cost 0.00205338
# step 1810, training accuracy 0.31808
# step 1810, cost 1.64722
# step 1810, change in cost 0.00205719
# step 1820, training accuracy 0.31901
# step 1820, cost 1.64516
# step 1820, change in cost 0.00206161
# step 1830, training accuracy 0.319568
# step 1830, cost 1.64309
# step 1830, change in cost 0.00206316
# step 1840, training accuracy 0.320406
# step 1840, cost 1.64103
# step 1840, change in cost 0.00206828
# step 1850, training accuracy 0.321057
# step 1850, cost 1.63896
# step 1850, change in cost 0.00207126
# step 1860, training accuracy 0.321336
# step 1860, cost 1.63688
# step 1860, change in cost 0.00207305
# step 1870, training accuracy 0.321708
# step 1870, cost 1.6348
# step 1870, change in cost 0.00207734
# step 1880, training accuracy 0.32208
# step 1880, cost 1.63273
# step 1880, change in cost 0.00207984
# step 1890, training accuracy 0.322359
# step 1890, cost 1.63064
# step 1890, change in cost 0.00208402
# step 1900, training accuracy 0.322731
# step 1900, cost 1.62855
# step 1900, change in cost 0.00208628
# step 1910, training accuracy 0.323475
# step 1910, cost 1.62647
# step 1910, change in cost 0.00208914
# step 1920, training accuracy 0.324033
# step 1920, cost 1.62437
# step 1920, change in cost 0.00209188
# step 1930, training accuracy 0.324777
# step 1930, cost 1.62228
# step 1930, change in cost 0.00209486
# step 1940, training accuracy 0.324963
# step 1940, cost 1.62018
# step 1940, change in cost 0.00209773
# step 1950, training accuracy 0.325707
# step 1950, cost 1.61808
# step 1950, change in cost 0.00209963
# step 1960, training accuracy 0.326451
# step 1960, cost 1.61598
# step 1960, change in cost 0.00210214
# step 1970, training accuracy 0.327009
# step 1970, cost 1.61387
# step 1970, change in cost 0.00210547
# step 1980, training accuracy 0.327846
# step 1980, cost 1.61177
# step 1980, change in cost 0.00210667
# step 1990, training accuracy 0.328125
# step 1990, cost 1.60966
# step 1990, change in cost 0.00210881
# step 2000, training accuracy 0.328869
# step 2000, cost 1.60755
# step 2000, change in cost 0.0021112
# step 2010, training accuracy 0.32952
# step 2010, cost 1.60543
# step 2010, change in cost 0.00211251
# step 2020, training accuracy 0.329985
# step 2020, cost 1.60332
# step 2020, change in cost 0.00211489
# step 2030, training accuracy 0.330543
# step 2030, cost 1.6012
# step 2030, change in cost 0.00211835
# step 2040, training accuracy 0.331008
# step 2040, cost 1.59908
# step 2040, change in cost 0.00211954
# step 2050, training accuracy 0.33138
# step 2050, cost 1.59696
# step 2050, change in cost 0.0021199
# step 2060, training accuracy 0.331752
# step 2060, cost 1.59484
# step 2060, change in cost 0.00212276
# step 2070, training accuracy 0.332217
# step 2070, cost 1.59272
# step 2070, change in cost 0.00212324
# step 2080, training accuracy 0.333054
# step 2080, cost 1.59059
# step 2080, change in cost 0.00212431
# step 2090, training accuracy 0.333612
# step 2090, cost 1.58846
# step 2090, change in cost 0.00212705
# step 2100, training accuracy 0.333891
# step 2100, cost 1.58634
# step 2100, change in cost 0.00212789
# step 2110, training accuracy 0.33417
# step 2110, cost 1.58421
# step 2110, change in cost 0.00212729
# step 2120, training accuracy 0.335007
# step 2120, cost 1.58208
# step 2120, change in cost 0.00213027
# step 2130, training accuracy 0.335565
# step 2130, cost 1.57995
# step 2130, change in cost 0.00213099
# step 2140, training accuracy 0.336217
# step 2140, cost 1.57782
# step 2140, change in cost 0.00213075
# step 2150, training accuracy 0.337054
# step 2150, cost 1.57569
# step 2150, change in cost 0.00213206
# step 2160, training accuracy 0.337519
# step 2160, cost 1.57355
# step 2160, change in cost 0.00213313
# step 2170, training accuracy 0.337984
# step 2170, cost 1.57142
# step 2170, change in cost 0.00213253
# step 2180, training accuracy 0.338635
# step 2180, cost 1.56928
# step 2180, change in cost 0.00213504
# step 2190, training accuracy 0.339565
# step 2190, cost 1.56715
# step 2190, change in cost 0.00213456
# step 2200, training accuracy 0.340123
# step 2200, cost 1.56502
# step 2200, change in cost 0.00213277
# step 2210, training accuracy 0.340774
# step 2210, cost 1.56288
# step 2210, change in cost 0.00213528
# step 2220, training accuracy 0.341146
# step 2220, cost 1.56075
# step 2220, change in cost 0.00213408
# step 2230, training accuracy 0.341704
# step 2230, cost 1.55861
# step 2230, change in cost 0.00213349
# step 2240, training accuracy 0.342262
# step 2240, cost 1.55648
# step 2240, change in cost 0.00213373
# step 2250, training accuracy 0.342727
# step 2250, cost 1.55435
# step 2250, change in cost 0.00213337
# step 2260, training accuracy 0.343285
# step 2260, cost 1.55221
# step 2260, change in cost 0.00213277
# step 2270, training accuracy 0.344122
# step 2270, cost 1.55008
# step 2270, change in cost 0.00213313
# step 2280, training accuracy 0.344587
# step 2280, cost 1.54795
# step 2280, change in cost 0.00213146
# step 2290, training accuracy 0.345052
# step 2290, cost 1.54582
# step 2290, change in cost 0.00213265
# step 2300, training accuracy 0.345703
# step 2300, cost 1.54369
# step 2300, change in cost 0.0021311
# step 2310, training accuracy 0.346261
# step 2310, cost 1.54156
# step 2310, change in cost 0.00213063
# step 2320, training accuracy 0.346726
# step 2320, cost 1.53943
# step 2320, change in cost 0.00212944
# step 2330, training accuracy 0.34747
# step 2330, cost 1.5373
# step 2330, change in cost 0.00212753
# step 2340, training accuracy 0.347749
# step 2340, cost 1.53517
# step 2340, change in cost 0.0021286
# step 2350, training accuracy 0.348772
# step 2350, cost 1.53305
# step 2350, change in cost 0.00212395
# step 2360, training accuracy 0.349144
# step 2360, cost 1.53092
# step 2360, change in cost 0.00212669
# step 2370, training accuracy 0.349423
# step 2370, cost 1.5288
# step 2370, change in cost 0.00212204
# step 2380, training accuracy 0.350074
# step 2380, cost 1.52667
# step 2380, change in cost 0.00212324
# step 2390, training accuracy 0.350446
# step 2390, cost 1.52455
# step 2390, change in cost 0.00212169
# step 2400, training accuracy 0.351097
# step 2400, cost 1.52243
# step 2400, change in cost 0.00211906
# step 2410, training accuracy 0.351283
# step 2410, cost 1.52032
# step 2410, change in cost 0.00211728
# step 2420, training accuracy 0.351562
# step 2420, cost 1.5182
# step 2420, change in cost 0.00211704
# step 2430, training accuracy 0.351749
# step 2430, cost 1.51608
# step 2430, change in cost 0.00211465
# step 2440, training accuracy 0.352214
# step 2440, cost 1.51397
# step 2440, change in cost 0.0021131
# step 2450, training accuracy 0.352772
# step 2450, cost 1.51186
# step 2450, change in cost 0.00211167
# step 2460, training accuracy 0.353144
# step 2460, cost 1.50975
# step 2460, change in cost 0.00210905
# step 2470, training accuracy 0.353609
# step 2470, cost 1.50764
# step 2470, change in cost 0.00210774
# step 2480, training accuracy 0.353795
# step 2480, cost 1.50554
# step 2480, change in cost 0.00210559
# step 2490, training accuracy 0.354539
# step 2490, cost 1.50343
# step 2490, change in cost 0.00210345
# step 2500, training accuracy 0.354911
# step 2500, cost 1.50133
# step 2500, change in cost 0.00210178
# step 2510, training accuracy 0.355748
# step 2510, cost 1.49923
# step 2510, change in cost 0.00209856
# step 2520, training accuracy 0.356399
# step 2520, cost 1.49714
# step 2520, change in cost 0.00209761
# step 2530, training accuracy 0.356678
# step 2530, cost 1.49504
# step 2530, change in cost 0.00209701
# step 2540, training accuracy 0.356864
# step 2540, cost 1.49295
# step 2540, change in cost 0.00209236
# step 2550, training accuracy 0.357608
# step 2550, cost 1.49086
# step 2550, change in cost 0.00209117
# step 2560, training accuracy 0.358166
# step 2560, cost 1.48877
# step 2560, change in cost 0.00208735
# step 2570, training accuracy 0.358259
# step 2570, cost 1.48668
# step 2570, change in cost 0.00208724
# step 2580, training accuracy 0.358817
# step 2580, cost 1.4846
# step 2580, change in cost 0.00208306
# step 2590, training accuracy 0.359375
# step 2590, cost 1.48252
# step 2590, change in cost 0.00208187
# step 2600, training accuracy 0.35984
# step 2600, cost 1.48044
# step 2600, change in cost 0.00207889
# step 2610, training accuracy 0.360026
# step 2610, cost 1.47836
# step 2610, change in cost 0.00207627
# step 2620, training accuracy 0.360398
# step 2620, cost 1.47629
# step 2620, change in cost 0.00207376
# step 2630, training accuracy 0.360863
# step 2630, cost 1.47422
# step 2630, change in cost 0.0020715
# step 2640, training accuracy 0.361421
# step 2640, cost 1.47215
# step 2640, change in cost 0.002069
# step 2650, training accuracy 0.362165
# step 2650, cost 1.47008
# step 2650, change in cost 0.00206637
# step 2660, training accuracy 0.362537
# step 2660, cost 1.46802
# step 2660, change in cost 0.0020622
# step 2670, training accuracy 0.362909
# step 2670, cost 1.46596
# step 2670, change in cost 0.00206196
# step 2680, training accuracy 0.363374
# step 2680, cost 1.4639
# step 2680, change in cost 0.0020566
# step 2690, training accuracy 0.363932
# step 2690, cost 1.46184
# step 2690, change in cost 0.00205564
# step 2700, training accuracy 0.364025
# step 2700, cost 1.45979
# step 2700, change in cost 0.00205219
# step 2710, training accuracy 0.364583
# step 2710, cost 1.45774
# step 2710, change in cost 0.00204813
# step 2720, training accuracy 0.364862
# step 2720, cost 1.4557
# step 2720, change in cost 0.00204551
# step 2730, training accuracy 0.365699
# step 2730, cost 1.45365
# step 2730, change in cost 0.00204289
# step 2740, training accuracy 0.366164
# step 2740, cost 1.45161
# step 2740, change in cost 0.00204015
# step 2750, training accuracy 0.366443
# step 2750, cost 1.44958
# step 2750, change in cost 0.00203633
# step 2760, training accuracy 0.367001
# step 2760, cost 1.44755
# step 2760, change in cost 0.00203216
# step 2770, training accuracy 0.367653
# step 2770, cost 1.44552
# step 2770, change in cost 0.00203025
# step 2780, training accuracy 0.368211
# step 2780, cost 1.44349
# step 2780, change in cost 0.00202549
# step 2790, training accuracy 0.368676
# step 2790, cost 1.44147
# step 2790, change in cost 0.00202322
# step 2800, training accuracy 0.368862
# step 2800, cost 1.43945
# step 2800, change in cost 0.00201964
# step 2810, training accuracy 0.369327
# step 2810, cost 1.43743
# step 2810, change in cost 0.00201607
# step 2820, training accuracy 0.369699
# step 2820, cost 1.43542
# step 2820, change in cost 0.00201166
# step 2830, training accuracy 0.369978
# step 2830, cost 1.43341
# step 2830, change in cost 0.00200832
# step 2840, training accuracy 0.370443
# step 2840, cost 1.43141
# step 2840, change in cost 0.00200462
# step 2850, training accuracy 0.370815
# step 2850, cost 1.4294
# step 2850, change in cost 0.00200248
# step 2860, training accuracy 0.37128
# step 2860, cost 1.42741
# step 2860, change in cost 0.00199676
# step 2870, training accuracy 0.371559
# step 2870, cost 1.42541
# step 2870, change in cost 0.00199282
# step 2880, training accuracy 0.371931
# step 2880, cost 1.42342
# step 2880, change in cost 0.0019908
# step 2890, training accuracy 0.372861
# step 2890, cost 1.42144
# step 2890, change in cost 0.00198472
# step 2900, training accuracy 0.373326
# step 2900, cost 1.41946
# step 2900, change in cost 0.00198197
# step 2910, training accuracy 0.373698
# step 2910, cost 1.41748
# step 2910, change in cost 0.0019778
# step 2920, training accuracy 0.374535
# step 2920, cost 1.41551
# step 2920, change in cost 0.00197411
# step 2930, training accuracy 0.375279
# step 2930, cost 1.41354
# step 2930, change in cost 0.0019691
# step 2940, training accuracy 0.375837
# step 2940, cost 1.41157
# step 2940, change in cost 0.00196588
# step 2950, training accuracy 0.376116
# step 2950, cost 1.40961
# step 2950, change in cost 0.00196004
# step 2960, training accuracy 0.37686
# step 2960, cost 1.40765
# step 2960, change in cost 0.00195837
# step 2970, training accuracy 0.377418
# step 2970, cost 1.4057
# step 2970, change in cost 0.00195217
# step 2980, training accuracy 0.377883
# step 2980, cost 1.40375
# step 2980, change in cost 0.00194776
# step 2990, training accuracy 0.377976
# step 2990, cost 1.40181
# step 2990, change in cost 0.00194585
# step 3000, training accuracy 0.378348
# step 3000, cost 1.39987
# step 3000, change in cost 0.00193977
# step 3010, training accuracy 0.378627
# step 3010, cost 1.39793
# step 3010, change in cost 0.00193584
# step 3020, training accuracy 0.379092
# step 3020, cost 1.396
# step 3020, change in cost 0.00193191
# step 3030, training accuracy 0.379557
# step 3030, cost 1.39407
# step 3030, change in cost 0.0019263
# step 3040, training accuracy 0.380301
# step 3040, cost 1.39215
# step 3040, change in cost 0.00192344
# step 3050, training accuracy 0.380673
# step 3050, cost 1.39023
# step 3050, change in cost 0.00191832
# step 3060, training accuracy 0.380766
# step 3060, cost 1.38832
# step 3060, change in cost 0.00191343
# step 3070, training accuracy 0.381417
# step 3070, cost 1.38641
# step 3070, change in cost 0.00190902
# step 3080, training accuracy 0.381789
# step 3080, cost 1.3845
# step 3080, change in cost 0.0019052
# step 3090, training accuracy 0.382254
# step 3090, cost 1.3826
# step 3090, change in cost 0.00190127
# step 3100, training accuracy 0.382719
# step 3100, cost 1.38071
# step 3100, change in cost 0.00189638
# step 3110, training accuracy 0.383836
# step 3110, cost 1.37881
# step 3110, change in cost 0.00189149
# step 3120, training accuracy 0.384394
# step 3120, cost 1.37693
# step 3120, change in cost 0.00188756
# step 3130, training accuracy 0.38458
# step 3130, cost 1.37504
# step 3130, change in cost 0.00188196
# step 3140, training accuracy 0.385231
# step 3140, cost 1.37317
# step 3140, change in cost 0.00187695
# step 3150, training accuracy 0.385417
# step 3150, cost 1.37129
# step 3150, change in cost 0.00187528
# step 3160, training accuracy 0.386068
# step 3160, cost 1.36942
# step 3160, change in cost 0.00186968
# step 3170, training accuracy 0.386719
# step 3170, cost 1.36756
# step 3170, change in cost 0.00186443
# step 3180, training accuracy 0.386998
# step 3180, cost 1.3657
# step 3180, change in cost 0.0018611
# step 3190, training accuracy 0.387742
# step 3190, cost 1.36384
# step 3190, change in cost 0.00185525
# step 3200, training accuracy 0.388858
# step 3200, cost 1.36199
# step 3200, change in cost 0.00185263
# step 3210, training accuracy 0.389137
# step 3210, cost 1.36014
# step 3210, change in cost 0.00184703
# step 3220, training accuracy 0.389509
# step 3220, cost 1.3583
# step 3220, change in cost 0.0018425
# step 3230, training accuracy 0.389881
# step 3230, cost 1.35646
# step 3230, change in cost 0.00183785
# step 3240, training accuracy 0.390532
# step 3240, cost 1.35463
# step 3240, change in cost 0.00183463
# step 3250, training accuracy 0.391369
# step 3250, cost 1.3528
# step 3250, change in cost 0.00182998
# step 3260, training accuracy 0.391834
# step 3260, cost 1.35097
# step 3260, change in cost 0.00182617
# step 3270, training accuracy 0.391927
# step 3270, cost 1.34915
# step 3270, change in cost 0.00182045
# step 3280, training accuracy 0.392113
# step 3280, cost 1.34733
# step 3280, change in cost 0.00181675
# step 3290, training accuracy 0.392578
# step 3290, cost 1.34552
# step 3290, change in cost 0.0018127
# step 3300, training accuracy 0.39295
# step 3300, cost 1.34371
# step 3300, change in cost 0.00180709
# step 3310, training accuracy 0.393508
# step 3310, cost 1.34191
# step 3310, change in cost 0.00180519
# step 3320, training accuracy 0.39388
# step 3320, cost 1.34011
# step 3320, change in cost 0.00179946
# step 3330, training accuracy 0.394531
# step 3330, cost 1.33831
# step 3330, change in cost 0.0017947
# step 3340, training accuracy 0.394717
# step 3340, cost 1.33652
# step 3340, change in cost 0.00179207
# step 3350, training accuracy 0.394996
# step 3350, cost 1.33474
# step 3350, change in cost 0.00178695
# step 3360, training accuracy 0.395275
# step 3360, cost 1.33295
# step 3360, change in cost 0.00178218
# step 3370, training accuracy 0.395647
# step 3370, cost 1.33117
# step 3370, change in cost 0.00177956
# step 3380, training accuracy 0.396298
# step 3380, cost 1.3294
# step 3380, change in cost 0.00177395
# step 3390, training accuracy 0.397135
# step 3390, cost 1.32763
# step 3390, change in cost 0.00177026
# step 3400, training accuracy 0.3976
# step 3400, cost 1.32586
# step 3400, change in cost 0.00176644
# step 3410, training accuracy 0.398531
# step 3410, cost 1.3241
# step 3410, change in cost 0.00176227
# step 3420, training accuracy 0.399089
# step 3420, cost 1.32234
# step 3420, change in cost 0.00175738
# step 3430, training accuracy 0.399554
# step 3430, cost 1.32059
# step 3430, change in cost 0.00175416
# step 3440, training accuracy 0.39974
# step 3440, cost 1.31884
# step 3440, change in cost 0.00174963
# step 3450, training accuracy 0.400112
# step 3450, cost 1.31709
# step 3450, change in cost 0.00174642
# step 3460, training accuracy 0.400763
# step 3460, cost 1.31535
# step 3460, change in cost 0.00174105
# step 3470, training accuracy 0.400949
# step 3470, cost 1.31361
# step 3470, change in cost 0.00173736
# step 3480, training accuracy 0.401414
# step 3480, cost 1.31188
# step 3480, change in cost 0.00173497
# step 3490, training accuracy 0.4016
# step 3490, cost 1.31015
# step 3490, change in cost 0.00172746
# step 3500, training accuracy 0.402251
# step 3500, cost 1.30843
# step 3500, change in cost 0.0017252
# step 3510, training accuracy 0.402437
# step 3510, cost 1.30671
# step 3510, change in cost 0.00172079
# step 3520, training accuracy 0.402902
# step 3520, cost 1.30499
# step 3520, change in cost 0.00171793
# step 3530, training accuracy 0.403274
# step 3530, cost 1.30328
# step 3530, change in cost 0.00171292
# step 3540, training accuracy 0.403925
# step 3540, cost 1.30157
# step 3540, change in cost 0.00170851
# step 3550, training accuracy 0.404576
# step 3550, cost 1.29986
# step 3550, change in cost 0.0017035
# step 3560, training accuracy 0.405041
# step 3560, cost 1.29816
# step 3560, change in cost 0.00170159
# step 3570, training accuracy 0.40532
# step 3570, cost 1.29647
# step 3570, change in cost 0.00169504
# step 3580, training accuracy 0.405506
# step 3580, cost 1.29478
# step 3580, change in cost 0.0016917
# step 3590, training accuracy 0.406343
# step 3590, cost 1.29309
# step 3590, change in cost 0.001688
# step 3600, training accuracy 0.406901
# step 3600, cost 1.2914
# step 3600, change in cost 0.00168407
# step 3610, training accuracy 0.407366
# step 3610, cost 1.28972
# step 3610, change in cost 0.0016799
# step 3620, training accuracy 0.407459
# step 3620, cost 1.28805
# step 3620, change in cost 0.0016737
# step 3630, training accuracy 0.408017
# step 3630, cost 1.28638
# step 3630, change in cost 0.00167179
# step 3640, training accuracy 0.408482
# step 3640, cost 1.28471
# step 3640, change in cost 0.00166571
# step 3650, training accuracy 0.408854
# step 3650, cost 1.28305
# step 3650, change in cost 0.00166297
# step 3660, training accuracy 0.409412
# step 3660, cost 1.28139
# step 3660, change in cost 0.00165808
# step 3670, training accuracy 0.40997
# step 3670, cost 1.27974
# step 3670, change in cost 0.00165248
# step 3680, training accuracy 0.410807
# step 3680, cost 1.27809
# step 3680, change in cost 0.00164926
# step 3690, training accuracy 0.4109
# step 3690, cost 1.27644
# step 3690, change in cost 0.00164461
# step 3700, training accuracy 0.411365
# step 3700, cost 1.2748
# step 3700, change in cost 0.00164032
# step 3710, training accuracy 0.411923
# step 3710, cost 1.27317
# step 3710, change in cost 0.0016346
# step 3720, training accuracy 0.412574
# step 3720, cost 1.27154
# step 3720, change in cost 0.00163078
# step 3730, training accuracy 0.412946
# step 3730, cost 1.26991
# step 3730, change in cost 0.00162721
# step 3740, training accuracy 0.413225
# step 3740, cost 1.26829
# step 3740, change in cost 0.00162137
# step 3750, training accuracy 0.413318
# step 3750, cost 1.26667
# step 3750, change in cost 0.00161672
# step 3760, training accuracy 0.413597
# step 3760, cost 1.26506
# step 3760, change in cost 0.00161242
# step 3770, training accuracy 0.413969
# step 3770, cost 1.26345
# step 3770, change in cost 0.00160682
# step 3780, training accuracy 0.414342
# step 3780, cost 1.26185
# step 3780, change in cost 0.00160289
# step 3790, training accuracy 0.4149
# step 3790, cost 1.26025
# step 3790, change in cost 0.0015986
# step 3800, training accuracy 0.415272
# step 3800, cost 1.25866
# step 3800, change in cost 0.00159216
# step 3810, training accuracy 0.415365
# step 3810, cost 1.25707
# step 3810, change in cost 0.00158823
# step 3820, training accuracy 0.415737
# step 3820, cost 1.25549
# step 3820, change in cost 0.00158262
# step 3830, training accuracy 0.416109
# step 3830, cost 1.25391
# step 3830, change in cost 0.00157881
# step 3840, training accuracy 0.416481
# step 3840, cost 1.25234
# step 3840, change in cost 0.00157237
# step 3850, training accuracy 0.416853
# step 3850, cost 1.25077
# step 3850, change in cost 0.0015676
# step 3860, training accuracy 0.417039
# step 3860, cost 1.24921
# step 3860, change in cost 0.00156331
# step 3870, training accuracy 0.417411
# step 3870, cost 1.24765
# step 3870, change in cost 0.0015583
# step 3880, training accuracy 0.41769
# step 3880, cost 1.2461
# step 3880, change in cost 0.00155187
# step 3890, training accuracy 0.418155
# step 3890, cost 1.24455
# step 3890, change in cost 0.00154686
# step 3900, training accuracy 0.418248
# step 3900, cost 1.24301
# step 3900, change in cost 0.00154126
# step 3910, training accuracy 0.418434
# step 3910, cost 1.24147
# step 3910, change in cost 0.00153625
# step 3920, training accuracy 0.418713
# step 3920, cost 1.23994
# step 3920, change in cost 0.00153065
# step 3930, training accuracy 0.419085
# step 3930, cost 1.23842
# step 3930, change in cost 0.00152588
# step 3940, training accuracy 0.419364
# step 3940, cost 1.2369
# step 3940, change in cost 0.00151944
# step 3950, training accuracy 0.419736
# step 3950, cost 1.23538
# step 3950, change in cost 0.00151479
# step 3960, training accuracy 0.420294
# step 3960, cost 1.23387
# step 3960, change in cost 0.001508
# step 3970, training accuracy 0.42048
# step 3970, cost 1.23237
# step 3970, change in cost 0.00150311
# step 3980, training accuracy 0.420666
# step 3980, cost 1.23087
# step 3980, change in cost 0.00149739
# step 3990, training accuracy 0.421038
# step 3990, cost 1.22938
# step 3990, change in cost 0.00149047
# step 4000, training accuracy 0.421131
# step 4000, cost 1.2279
# step 4000, change in cost 0.0014863
# step 4010, training accuracy 0.421224
# step 4010, cost 1.22642
# step 4010, change in cost 0.00148046
# step 4020, training accuracy 0.421317
# step 4020, cost 1.22494
# step 4020, change in cost 0.0014745
# step 4030, training accuracy 0.421596
# step 4030, cost 1.22348
# step 4030, change in cost 0.00146627
# step 4040, training accuracy 0.422154
# step 4040, cost 1.22201
# step 4040, change in cost 0.0014627
# step 4050, training accuracy 0.422154
# step 4050, cost 1.22056
# step 4050, change in cost 0.00145471
# step 4060, training accuracy 0.422433
# step 4060, cost 1.21911
# step 4060, change in cost 0.00145149
# step 4070, training accuracy 0.422898
# step 4070, cost 1.21766
# step 4070, change in cost 0.00144351
# step 4080, training accuracy 0.423177
# step 4080, cost 1.21623
# step 4080, change in cost 0.00143814
# step 4090, training accuracy 0.423921
# step 4090, cost 1.21479
# step 4090, change in cost 0.0014317
# step 4100, training accuracy 0.424572
# step 4100, cost 1.21337
# step 4100, change in cost 0.00142598
# step 4110, training accuracy 0.425223
# step 4110, cost 1.21195
# step 4110, change in cost 0.00141978
# step 4120, training accuracy 0.425502
# step 4120, cost 1.21054
# step 4120, change in cost 0.00141275
# step 4130, training accuracy 0.42606
# step 4130, cost 1.20913
# step 4130, change in cost 0.00140607
# step 4140, training accuracy 0.426525
# step 4140, cost 1.20773
# step 4140, change in cost 0.00140238
# step 4150, training accuracy 0.426525
# step 4150, cost 1.20633
# step 4150, change in cost 0.00139511
# step 4160, training accuracy 0.427083
# step 4160, cost 1.20494
# step 4160, change in cost 0.00138795
# step 4170, training accuracy 0.427269
# step 4170, cost 1.20356
# step 4170, change in cost 0.00138152
# step 4180, training accuracy 0.427734
# step 4180, cost 1.20219
# step 4180, change in cost 0.00137639
# step 4190, training accuracy 0.42792
# step 4190, cost 1.20082
# step 4190, change in cost 0.00136912
# step 4200, training accuracy 0.428106
# step 4200, cost 1.19945
# step 4200, change in cost 0.00136399
# step 4210, training accuracy 0.428757
# step 4210, cost 1.1981
# step 4210, change in cost 0.0013566
# step 4220, training accuracy 0.429036
# step 4220, cost 1.19675
# step 4220, change in cost 0.00135076
# step 4230, training accuracy 0.429408
# step 4230, cost 1.1954
# step 4230, change in cost 0.00134385
# step 4240, training accuracy 0.429594
# step 4240, cost 1.19406
# step 4240, change in cost 0.00133836
# step 4250, training accuracy 0.429967
# step 4250, cost 1.19273
# step 4250, change in cost 0.00133193
# step 4260, training accuracy 0.430153
# step 4260, cost 1.19141
# step 4260, change in cost 0.00132394
# step 4270, training accuracy 0.430339
# step 4270, cost 1.19009
# step 4270, change in cost 0.00131822
# step 4280, training accuracy 0.430432
# step 4280, cost 1.18878
# step 4280, change in cost 0.00131369
# step 4290, training accuracy 0.430897
# step 4290, cost 1.18747
# step 4290, change in cost 0.00130475
# step 4300, training accuracy 0.431083
# step 4300, cost 1.18617
# step 4300, change in cost 0.00129902
# step 4310, training accuracy 0.431548
# step 4310, cost 1.18488
# step 4310, change in cost 0.00129318
# step 4320, training accuracy 0.43192
# step 4320, cost 1.18359
# step 4320, change in cost 0.00128686
# step 4330, training accuracy 0.432292
# step 4330, cost 1.18231
# step 4330, change in cost 0.00127971
# step 4340, training accuracy 0.432385
# step 4340, cost 1.18104
# step 4340, change in cost 0.00127411
# step 4350, training accuracy 0.432571
# step 4350, cost 1.17977
# step 4350, change in cost 0.00126684
# step 4360, training accuracy 0.43285
# step 4360, cost 1.17852
# step 4360, change in cost 0.00125539
# step 4370, training accuracy 0.433315
# step 4370, cost 1.17726
# step 4370, change in cost 0.00125527
# step 4380, training accuracy 0.433501
# step 4380, cost 1.17601
# step 4380, change in cost 0.00125086
# step 4390, training accuracy 0.433687
# step 4390, cost 1.17477
# step 4390, change in cost 0.00123763
# step 4400, training accuracy 0.433966
# step 4400, cost 1.17354
# step 4400, change in cost 0.00123572
# step 4410, training accuracy 0.434245
# step 4410, cost 1.17231
# step 4410, change in cost 0.00122702
# step 4420, training accuracy 0.434617
# step 4420, cost 1.17109
# step 4420, change in cost 0.00122106
# step 4430, training accuracy 0.434989
# step 4430, cost 1.16987
# step 4430, change in cost 0.00121343
# step 4440, training accuracy 0.435361
# step 4440, cost 1.16867
# step 4440, change in cost 0.00120747
# step 4450, training accuracy 0.43564
# step 4450, cost 1.16746
# step 4450, change in cost 0.00120306
# step 4460, training accuracy 0.435826
# step 4460, cost 1.16627
# step 4460, change in cost 0.00119317
# step 4470, training accuracy 0.436198
# step 4470, cost 1.16508
# step 4470, change in cost 0.00118852
# step 4480, training accuracy 0.436198
# step 4480, cost 1.1639
# step 4480, change in cost 0.00118196
# step 4490, training accuracy 0.436291
# step 4490, cost 1.16272
# step 4490, change in cost 0.001176
# step 4500, training accuracy 0.436849
# step 4500, cost 1.16156
# step 4500, change in cost 0.00116873
# step 4510, training accuracy 0.437221
# step 4510, cost 1.16039
# step 4510, change in cost 0.00116301
# step 4520, training accuracy 0.437314
# step 4520, cost 1.15924
# step 4520, change in cost 0.00115156
# step 4530, training accuracy 0.437221
# step 4530, cost 1.15809
# step 4530, change in cost 0.00114727
# step 4540, training accuracy 0.4375
# step 4540, cost 1.15695
# step 4540, change in cost 0.00114727
# step 4550, training accuracy 0.437686
# step 4550, cost 1.15581
# step 4550, change in cost 0.00113428
# step 4560, training accuracy 0.437965
# step 4560, cost 1.15468
# step 4560, change in cost 0.0011276
# step 4570, training accuracy 0.437965
# step 4570, cost 1.15356
# step 4570, change in cost 0.00112271
# step 4580, training accuracy 0.438337
# step 4580, cost 1.15245
# step 4580, change in cost 0.00111389
# step 4590, training accuracy 0.438802
# step 4590, cost 1.15134
# step 4590, change in cost 0.00110841
# step 4600, training accuracy 0.439081
# step 4600, cost 1.15024
# step 4600, change in cost 0.00110233
# step 4610, training accuracy 0.43936
# step 4610, cost 1.14914
# step 4610, change in cost 0.00109673
# step 4620, training accuracy 0.439546
# step 4620, cost 1.14805
# step 4620, change in cost 0.00108874
# step 4630, training accuracy 0.439546
# step 4630, cost 1.14697
# step 4630, change in cost 0.0010829
# step 4640, training accuracy 0.440011
# step 4640, cost 1.14589
# step 4640, change in cost 0.00107622
# step 4650, training accuracy 0.440197
# step 4650, cost 1.14482
# step 4650, change in cost 0.0010705
# step 4660, training accuracy 0.440476
# step 4660, cost 1.14376
# step 4660, change in cost 0.00106454
# step 4670, training accuracy 0.440755
# step 4670, cost 1.1427
# step 4670, change in cost 0.00105786
# step 4680, training accuracy 0.440941
# step 4680, cost 1.14165
# step 4680, change in cost 0.00105023
# step 4690, training accuracy 0.44122
# step 4690, cost 1.1406
# step 4690, change in cost 0.00104511
# step 4700, training accuracy 0.441499
# step 4700, cost 1.13957
# step 4700, change in cost 0.00103843
# step 4710, training accuracy 0.441778
# step 4710, cost 1.13855
# step 4710, change in cost 0.00102007
# step 4720, training accuracy 0.441592
# step 4720, cost 1.13752
# step 4720, change in cost 0.0010227
# step 4730, training accuracy 0.441871
# step 4730, cost 1.1365
# step 4730, change in cost 0.00102806
# step 4740, training accuracy 0.442243
# step 4740, cost 1.13548
# step 4740, change in cost 0.00101185
# step 4750, training accuracy 0.442522
# step 4750, cost 1.13448
# step 4750, change in cost 0.0010035
# step 4760, training accuracy 0.442708
# step 4760, cost 1.13348
# step 4760, change in cost 0.000998378
# step 4770, training accuracy 0.44308
# step 4770, cost 1.13249
# step 4770, change in cost 0.000990272
# step 4780, training accuracy 0.443266
# step 4780, cost 1.13151
# step 4780, change in cost 0.000985622
# step 4790, training accuracy 0.443452
# step 4790, cost 1.13053
# step 4790, change in cost 0.000977397
# step 4800, training accuracy 0.443731
# step 4800, cost 1.12955
# step 4800, change in cost 0.000973582
# step 4810, training accuracy 0.44401
# step 4810, cost 1.12859
# step 4810, change in cost 0.000967145
# step 4820, training accuracy 0.444103
# step 4820, cost 1.12763
# step 4820, change in cost 0.00096035
# step 4830, training accuracy 0.44401
# step 4830, cost 1.12667
# step 4830, change in cost 0.000952721
# step 4840, training accuracy 0.44401
# step 4840, cost 1.12573
# step 4840, change in cost 0.000948548
# step 4850, training accuracy 0.444289
# step 4850, cost 1.12478
# step 4850, change in cost 0.000941634
# step 4860, training accuracy 0.444382
# step 4860, cost 1.12385
# step 4860, change in cost 0.000935316
# step 4870, training accuracy 0.444847
# step 4870, cost 1.12292
# step 4870, change in cost 0.00093019
# step 4880, training accuracy 0.445406
# step 4880, cost 1.122
# step 4880, change in cost 0.000923157
# step 4890, training accuracy 0.445592
# step 4890, cost 1.12108
# ...
# step 5760, training accuracy 0.454613
# step 5760, cost 1.06268
# step 5760, change in cost 0.000450969
# step 5770, training accuracy 0.454613
# step 5770, cost 1.0622
# step 5770, change in cost 0.000476122
# step 5780, training accuracy 0.454706
# step 5780, cost 1.06175
# step 5780, change in cost 0.000455856
# step 5790, training accuracy 0.454985
# step 5790, cost 1.06129
# step 5790, change in cost 0.000453711
# step 5800, training accuracy 0.454985
# step 5800, cost 1.06085
# step 5800, change in cost 0.000448227
# step 5810, training accuracy 0.455078
# step 5810, cost 1.0604
# step 5810, change in cost 0.000445485
# step 5820, training accuracy 0.455171
# step 5820, cost 1.05996
# step 5820, change in cost 0.000441909
# step 5830, training accuracy 0.455171
# step 5830, cost 1.05952
# step 5830, change in cost 0.000437617
# step 5840, training accuracy 0.455171
# step 5840, cost 1.05909
# step 5840, change in cost 0.000433922
# step 5850, training accuracy 0.455171
# step 5850, cost 1.05866
# step 5850, change in cost 0.000426054
# step 5860, training accuracy 0.455264
# step 5860, cost 1.05825
# step 5860, change in cost 0.000414729
# step 5870, training accuracy 0.455822
# step 5870, cost 1.05781
# step 5870, change in cost 0.000434518
# step 5880, training accuracy 0.455822
# step 5880, cost 1.05739
# step 5880, change in cost 0.000421524
# step 5890, training accuracy 0.455915
# step 5890, cost 1.05698
# step 5890, change in cost 0.000414371
# step 5900, training accuracy 0.455915
# step 5900, cost 1.05656
# step 5900, change in cost 0.000411034
# step 5910, training accuracy 0.456008
# step 5910, cost 1.05616
# step 5910, change in cost 0.000406742
# step 5920, training accuracy 0.456101
# step 5920, cost 1.05575
# step 5920, change in cost 0.000405669
# step 5930, training accuracy 0.456101
# step 5930, cost 1.05535
# step 5930, change in cost 0.000400305
# step 5940, training accuracy 0.456101
# step 5940, cost 1.05495
# step 5940, change in cost 0.000396609
# step 5950, training accuracy 0.456101
# step 5950, cost 1.05456
# step 5950, change in cost 0.000394344
# step 5960, training accuracy 0.456194
# step 5960, cost 1.05417
# step 5960, change in cost 0.00038898
# step 5970, training accuracy 0.45638
# step 5970, cost 1.05382
# step 5970, change in cost 0.000354648
# step 5980, training accuracy 0.456287
# step 5980, cost 1.05341
# step 5980, change in cost 0.000403523
# step 5990, training accuracy 0.456473
# step 5990, cost 1.05303
# step 5990, change in cost 0.000387669
# step 6000, training accuracy 0.456473
# step 6000, cost 1.05265
# step 6000, change in cost 0.000378966
# step 6010, training accuracy 0.456566
# step 6010, cost 1.05228
# step 6010, change in cost 0.00037086
# step 6020, training accuracy 0.456566
# step 6020, cost 1.05191
# step 6020, change in cost 0.000367999
# step 6030, training accuracy 0.456659
# step 6030, cost 1.05154
# step 6030, change in cost 0.000365376
# step 6040, training accuracy 0.456752
# step 6040, cost 1.05118
# step 6040, change in cost 0.000362754
# step 6050, training accuracy 0.456845
# step 6050, cost 1.05082
# step 6050, change in cost 0.000359654
# step 6060, training accuracy 0.456938
# step 6060, cost 1.05046
# step 6060, change in cost 0.00035584
# step 6070, training accuracy 0.456938
# step 6070, cost 1.05011
# step 6070, change in cost 0.000352025
# step 6080, training accuracy 0.457031
# step 6080, cost 1.04976
# step 6080, change in cost 0.000351667
# step 6090, training accuracy 0.457031
# step 6090, cost 1.04941
# step 6090, change in cost 0.000346303
# step 6100, training accuracy 0.457031
# step 6100, cost 1.04907
# step 6100, change in cost 0.000342607
# step 6110, training accuracy 0.457217
# step 6110, cost 1.04876
# step 6110, change in cost 0.000308633
# step 6120, training accuracy 0.457031
# step 6120, cost 1.0484
# step 6120, change in cost 0.000363827
# step 6130, training accuracy 0.457217
# step 6130, cost 1.04807
# step 6130, change in cost 0.000332713
# step 6140, training accuracy 0.457217
# step 6140, cost 1.04773
# step 6140, change in cost 0.000333905
# step 6150, training accuracy 0.457217
# step 6150, cost 1.0474
# step 6150, change in cost 0.000327945
# step 6160, training accuracy 0.45731
# step 6160, cost 1.04708
# step 6160, change in cost 0.000323772
# step 6170, training accuracy 0.45731
# step 6170, cost 1.04676
# step 6170, change in cost 0.000319958
# step 6180, training accuracy 0.45731
# step 6180, cost 1.04644
# step 6180, change in cost 0.000317931
# step 6190, training accuracy 0.45731
# step 6190, cost 1.04613
# step 6190, change in cost 0.000316262
# step 6200, training accuracy 0.45731
# step 6200, cost 1.04581
# step 6200, change in cost 0.000311852
# step 6210, training accuracy 0.45731
# step 6210, cost 1.0455
# step 6210, change in cost 0.000309944
# step 6220, training accuracy 0.45731
# step 6220, cost 1.0452
# step 6220, change in cost 0.000306368
# step 6230, training accuracy 0.45731
# step 6230, cost 1.04489
# step 6230, change in cost 0.000304818
# step 6240, training accuracy 0.457496
# step 6240, cost 1.0446
# step 6240, change in cost 0.000290036
# step 6250, training accuracy 0.457403
# step 6250, cost 1.04429
# step 6250, change in cost 0.000309467
# step 6260, training accuracy 0.457496
# step 6260, cost 1.04401
# step 6260, change in cost 0.000282764
# step 6270, training accuracy 0.457496
# step 6270, cost 1.04371
# step 6270, change in cost 0.000302076
# step 6280, training accuracy 0.457496
# step 6280, cost 1.04342
# step 6280, change in cost 0.00028646
# step 6290, training accuracy 0.457496
# step 6290, cost 1.04314
# step 6290, change in cost 0.000287771
# step 6300, training accuracy 0.457496
# step 6300, cost 1.04285
# step 6300, change in cost 0.000282645
# step 6310, training accuracy 0.457496
# step 6310, cost 1.04257
# step 6310, change in cost 0.000280619
# step 6320, training accuracy 0.457496
# step 6320, cost 1.04229
# step 6320, change in cost 0.0002774
# step 6330, training accuracy 0.457496
# step 6330, cost 1.04202
# step 6330, change in cost 0.000276327
# step 6340, training accuracy 0.457496
# step 6340, cost 1.04174
# step 6340, change in cost 0.000273585
# step 6350, training accuracy 0.457496
# step 6350, cost 1.04147
# step 6350, change in cost 0.00027144
# step 6360, training accuracy 0.457496
# step 6360, cost 1.04121
# step 6360, change in cost 0.000268102
# step 6370, training accuracy 0.457496
# step 6370, cost 1.04094
# step 6370, change in cost 0.000266075
# step 6380, training accuracy 0.457496
# step 6380, cost 1.04068
# step 6380, change in cost 0.00026381
# step 6390, training accuracy 0.457496
# step 6390, cost 1.04041
# step 6390, change in cost 0.000261426
# step 6400, training accuracy 0.457496
# step 6400, cost 1.04015
# step 6400, change in cost 0.00025928
# step 6410, training accuracy 0.457496
# step 6410, cost 1.0399
# step 6410, change in cost 0.000256419
# step 6420, training accuracy 0.457496
# step 6420, cost 1.03965
# step 6420, change in cost 0.000244141
# step 6430, training accuracy 0.457496
# step 6430, cost 1.03939
# step 6430, change in cost 0.000262022
# step 6440, training accuracy 0.457589
# step 6440, cost 1.03916
# step 6440, change in cost 0.000231624
# step 6450, training accuracy 0.457682
# step 6450, cost 1.0389
# step 6450, change in cost 0.000257492
# step 6460, training accuracy 0.457775
# step 6460, cost 1.03866
# step 6460, change in cost 0.00024426
# step 6470, training accuracy 0.457868
# step 6470, cost 1.03842
# step 6470, change in cost 0.000239372
# step 6480, training accuracy 0.457868
# step 6480, cost 1.03818
# step 6480, change in cost 0.00023973
# step 6490, training accuracy 0.457868
# step 6490, cost 1.03794
# step 6490, change in cost 0.000235081
# step 6500, training accuracy 0.457961
# step 6500, cost 1.03771
# step 6500, change in cost 0.000234008
# step 6510, training accuracy 0.458147
# step 6510, cost 1.03748
# step 6510, change in cost 0.000231862
# step 6520, training accuracy 0.45824
# step 6520, cost 1.03725
# step 6520, change in cost 0.000229239
# step 6530, training accuracy 0.45824
# step 6530, cost 1.03702
# step 6530, change in cost 0.000227332
# step 6540, training accuracy 0.45824
# step 6540, cost 1.0368
# step 6540, change in cost 0.000225663
# step 6550, training accuracy 0.45824
# step 6550, cost 1.03657
# step 6550, change in cost 0.000223398
# step 6560, training accuracy 0.45824
# step 6560, cost 1.03635
# step 6560, change in cost 0.000221848
# step 6570, training accuracy 0.45824
# step 6570, cost 1.03613
# step 6570, change in cost 0.000219464
# step 6580, training accuracy 0.458333
# step 6580, cost 1.03593
# step 6580, change in cost 0.000199795
# step 6590, training accuracy 0.458333
# step 6590, cost 1.0357
# step 6590, change in cost 0.000232697
# step 6600, training accuracy 0.458333
# step 6600, cost 1.03549
# step 6600, change in cost 0.000211358
# step 6610, training accuracy 0.458333
# step 6610, cost 1.03528
# step 6610, change in cost 0.000212431
# step 6620, training accuracy 0.458333
# step 6620, cost 1.03507
# step 6620, change in cost 0.000208855
# step 6630, training accuracy 0.458333
# step 6630, cost 1.03486
# step 6630, change in cost 0.000206709
# step 6640, training accuracy 0.458333
# step 6640, cost 1.03465
# step 6640, change in cost 0.000205636
# step 6650, training accuracy 0.458333
# step 6650, cost 1.03446
# step 6650, change in cost 0.000193834
# step 6660, training accuracy 0.458333
# step 6660, cost 1.03426
# step 6660, change in cost 0.00019908
# step 6670, training accuracy 0.458333
# step 6670, cost 1.03405
# step 6670, change in cost 0.000208974
# step 6680, training accuracy 0.458333
# step 6680, cost 1.03386
# step 6680, change in cost 0.000196099
# step 6690, training accuracy 0.458333
# step 6690, cost 1.03366
# step 6690, change in cost 0.000193477
# step 6700, training accuracy 0.458333
# step 6700, cost 1.03347
# step 6700, change in cost 0.000193357
# step 6710, training accuracy 0.458426
# step 6710, cost 1.03328
# step 6710, change in cost 0.00019145
# step 6720, training accuracy 0.458426
# step 6720, cost 1.03309
# step 6720, change in cost 0.000189662
# step 6730, training accuracy 0.458426
# step 6730, cost 1.0329
# step 6730, change in cost 0.000187278
# step 6740, training accuracy 0.458426
# step 6740, cost 1.03271
# step 6740, change in cost 0.000185966
# step 6750, training accuracy 0.458705
# step 6750, cost 1.03253
# step 6750, change in cost 0.000183344
# step 6760, training accuracy 0.458705
# step 6760, cost 1.03235
# step 6760, change in cost 0.000182748
# step 6770, training accuracy 0.458705
# step 6770, cost 1.03217
# step 6770, change in cost 0.000181556
# step 6780, training accuracy 0.458705
# step 6780, cost 1.03199
# step 6780, change in cost 0.000177383
# step 6790, training accuracy 0.458705
# step 6790, cost 1.03186
# step 6790, change in cost 0.000127673
# step 6800, training accuracy 0.458705
# step 6800, cost 1.03165
# step 6800, change in cost 0.000210404
# step 6810, training accuracy 0.458705
# step 6810, cost 1.03146
# step 6810, change in cost 0.000188589
# step 6820, training accuracy 0.458705
# step 6820, cost 1.03129
# step 6820, change in cost 0.00017035
# step 6830, training accuracy 0.458798
# step 6830, cost 1.03112
# step 6830, change in cost 0.000170469
# step 6840, training accuracy 0.458798
# step 6840, cost 1.03095
# step 6840, change in cost 0.0001688
# step 6850, training accuracy 0.458798
# step 6850, cost 1.03079
# step 6850, change in cost 0.000165939
# step 6860, training accuracy 0.458798
# step 6860, cost 1.03062
# step 6860, change in cost 0.000166059
# step 6870, training accuracy 0.458798
# step 6870, cost 1.03046
# step 6870, change in cost 0.000163317
# step 6880, training accuracy 0.458798
# step 6880, cost 1.0303
# step 6880, change in cost 0.000161767
# step 6890, training accuracy 0.458798
# step 6890, cost 1.03013
# step 6890, change in cost 0.000161767
# step 6900, training accuracy 0.458798
# step 6900, cost 1.02998
# step 6900, change in cost 0.000159025
# step 6910, training accuracy 0.458798
# step 6910, cost 1.02982
# step 6910, change in cost 0.000158548
# step 6920, training accuracy 0.458798
# step 6920, cost 1.02966
# step 6920, change in cost 0.000157475
# step 6930, training accuracy 0.458798
# step 6930, cost 1.02951
# step 6930, change in cost 0.000150919
# step 6940, training accuracy 0.458798
# step 6940, cost 1.02935
# step 6940, change in cost 0.000155687
# step 6950, training accuracy 0.458798
# step 6950, cost 1.02921
# step 6950, change in cost 0.000146031
# step 6960, training accuracy 0.458798
# step 6960, cost 1.02906
# step 6960, change in cost 0.000149131
# step 6970, training accuracy 0.458798
# step 6970, cost 1.0289
# step 6970, change in cost 0.000154495
# step 6980, training accuracy 0.458798
# step 6980, cost 1.02875
# step 6980, change in cost 0.000148416
# step 6990, training accuracy 0.458798
# step 6990, cost 1.02861
# step 6990, change in cost 0.000143886
# step 7000, training accuracy 0.458798
# step 7000, cost 1.02848
# step 7000, change in cost 0.000135779
# step 7010, training accuracy 0.458798
# step 7010, cost 1.02832
# step 7010, change in cost 0.000152946
# step 7020, training accuracy 0.458798
# step 7020, cost 1.02818
# step 7020, change in cost 0.000139594
# step 7030, training accuracy 0.458798
# step 7030, cost 1.02804
# step 7030, change in cost 0.000143647
# step 7040, training accuracy 0.458798
# step 7040, cost 1.0279
# step 7040, change in cost 0.000138879
# step 7050, training accuracy 0.458798
# step 7050, cost 1.02777
# step 7050, change in cost 0.000134468
# step 7060, training accuracy 0.458798
# step 7060, cost 1.02763
# step 7060, change in cost 0.000131011
# step 7070, training accuracy 0.458798
# step 7070, cost 1.0275
# step 7070, change in cost 0.000135183
# step 7080, training accuracy 0.458798
# step 7080, cost 1.02736
# step 7080, change in cost 0.000138402
# step 7090, training accuracy 0.458798
# step 7090, cost 1.02723
# step 7090, change in cost 0.000135064
# step 7100, training accuracy 0.458798
# step 7100, cost 1.0271
# step 7100, change in cost 0.000130892
# step 7110, training accuracy 0.458798
# step 7110, cost 1.02696
# step 7110, change in cost 0.000130415
# step 7120, training accuracy 0.458798
# step 7120, cost 1.02684
# step 7120, change in cost 0.000127077
# step 7130, training accuracy 0.458891
# step 7130, cost 1.02672
# step 7130, change in cost 0.000117898
# step 7140, training accuracy 0.458798
# step 7140, cost 1.02658
# step 7140, change in cost 0.000136495
# step 7150, training accuracy 0.458798
# step 7150, cost 1.02646
# step 7150, change in cost 0.000123858
# step 7160, training accuracy 0.458798
# step 7160, cost 1.02633
# step 7160, change in cost 0.000127316
# step 7170, training accuracy 0.458798
# step 7170, cost 1.02621
# step 7170, change in cost 0.000122428
# step 7180, training accuracy 0.458798
# step 7180, cost 1.02609
# step 7180, change in cost 0.000122666
# step 7190, training accuracy 0.458891
# step 7190, cost 1.02597
# step 7190, change in cost 0.000121117
# step 7200, training accuracy 0.458891
# step 7200, cost 1.02585
# step 7200, change in cost 0.000117302
# step 7210, training accuracy 0.458891
# step 7210, cost 1.02576
# step 7210, change in cost 8.44002e-05
# change in cost 8.44002e-05; convergence.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-9d8f4e67afce> in <module>()
#      47 print("final accuracy on test set: %s" %str(sess.run(accuracy,
#      48                                                      feed_dict={x: testX,
# ---> 49                                                                 y: testY})))
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     942                 'Cannot feed value of shape %r for Tensor %r, '
#     943                 'which has shape %r'
# --> 944                 % (np_val.shape, subfeed_t.name, str(subfeed_t.get_shape())))
#     945           if not self.graph.is_feedable(subfeed_t):
#     946             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (2688, 100) for Tensor u'Placeholder:0', which has shape '(?, 1, 100)'

# %%
testX = testX.reshape(2688,1,100)
print("final accuracy on test set: %s" %str(sess.run(accuracy, 
                                                     feed_dict={x: testX, 
                                                                y: testY})))
# Out:
# final accuracy on test set: 0.0822173
